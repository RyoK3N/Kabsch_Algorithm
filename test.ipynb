# %%
#Elbow detection algorithm
#load the image
#mark keypoints on the image
#connect edges of the keypoints
#measured the angle created by line l1 and l2 on the elbow point e1

# %%
print(cv2.__version__)
# Out:
# 4.5.5
